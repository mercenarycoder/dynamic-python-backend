# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# Importing the dataset

# %%
dataset = pd.read_csv("./retail_sales.csv")
#Manually creating a array to track which are the Numerical columns from the given DATA
numeric_columns = ['Quantity','Price','Sales']
#this will convert the columns to numeric data type which removes
#error due to absence of data
for col in numeric_columns:
    dataset[col] = pd.to_numeric(dataset[col], errors='coerce')
    
print(dataset.dtypes)

numerical_cols = dataset.select_dtypes(
    include=['int64','float64']
).columns 

categorical_cols = dataset.select_dtypes(
    include=['object','str']
).columns

X = dataset.iloc[:,1:5].values
Y = dataset.iloc[:,[0,5,6,7]].values
Z = dataset.iloc[:, -1].values

print(Y)
print(Z)
# Out:
# OrderID              int64
# State                  str
# City                   str
# Product                str
# Category               str
# Quantity             int64
# Price              float64
# Sales              float64
# Eligible_For_AI        str
# dtype: object
# [[  1001.      2.  55000. 110000.]
#  [  1002.      3.  30000.  90000.]
#  [  1003.      5.     nan  10000.]
#  [  1004.      2.  15000.  30000.]
#  [  1005.     10.   1500.  15000.]
#  [  1006.      8.    700.   5600.]
#  [  1007.      4.  25000. 100000.]
#  [  1008.      1.  60000.     nan]
#  [  1009.      2.     nan     nan]
#  [  1010.      3.  12000.  36000.]
#  [  1011.      2.  45000.  90000.]
#  [  1012.      6.   3500.  21000.]
#  [  1013.      5.  32000. 160000.]
#  [  1014.      7.   8000.  56000.]
#  [  1015.      2.  58000. 116000.]]
# <StringArray>
# ['yes', 'yes',  'no', 'yes',  'no',  'no', 'yes', 'yes',   nan, 'yes', 'yes',
#   'no', 'yes',  'no', 'yes']
# Length: 15, dtype: str

# %% [markdown]
# Fill the missing data so that it can be consistent

# %%
from sklearn.impute import SimpleImputer

data = np.array(Y)
imputer = SimpleImputer(missing_values=np.nan, strategy='mean')
Y = imputer.fit_transform(data)
np.set_printoptions(suppress=True)
print(X)
print(Y)
# Out:
# [['Karnataka' 'Bangalore' 'Laptop' 'Electronics']
#  ['Maharashtra' 'Mumbai' 'Phone' 'Electronics']
#  ['Telangana' 'Hyderabad' 'Headphones' 'Accessories']
#  ['Tamil Nadu' 'Chennai' 'Monitor' 'Electronics']
#  ['Delhi' 'New Delhi' 'Keyboard' 'Accessories']
#  ['Karnataka' 'Mysore' 'Mouse' 'Accessories']
#  ['West Bengal' 'Kolkata' 'Tablet' 'Electronics']
#  ['Maharashtra' 'Pune' 'Laptop' 'Electronics']
#  ['Gujarat' 'Ahmedabad' 'Phone' 'Electronics']
#  ['Rajasthan' 'Jaipur' 'Printer' 'Electronics']
#  ['Uttar Pradesh' 'Lucknow' 'Camera' 'Electronics']
#  ['Kerala' 'Kochi' 'Speaker' 'Accessories']
#  ['Karnataka' 'Bangalore' 'Phone' 'Electronics']
#  ['Maharashtra' 'Mumbai' 'Smart Watch' 'Accessories']
#  ['Telangana' 'Hyderabad' 'Laptop' 'Electronics']]
# [[  1001.              2.          55000.         110000.        ]
#  [  1002.              3.          30000.          90000.        ]
#  [  1003.              5.          26592.30769231  10000.        ]
#  [  1004.              2.          15000.          30000.        ]
#  [  1005.             10.           1500.          15000.        ]
#  [  1006.              8.            700.           5600.        ]
#  [  1007.              4.          25000.         100000.        ]
#  [  1008.              1.          60000.          64584.61538462]
#  [  1009.              2.          26592.30769231  64584.61538462]
#  [  1010.              3.          12000.          36000.        ]
#  [  1011.              2.          45000.          90000.        ]
#  [  1012.              6.           3500.          21000.        ]
#  [  1013.              5.          32000.         160000.        ]
#  [  1014.              7.           8000.          56000.        ]
#  [  1015.              2.          58000.         116000.        ]]

# %% [markdown]
# Encoding the Independent Variable

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
 
ct = ColumnTransformer(transformers=[('encoder', 
                       OneHotEncoder(sparse_output=False),
                       [0])],
                       remainder='passthrough')
X = ct.fit_transform(X)
print(X)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[41], line 8
#       4 ct = ColumnTransformer(transformers=[('encoder',
#       5                        OneHotEncoder(sparse_output=False),
#       6                        [0])],
#       7                        remainder='passthrough')
# ----> 8 X = ct.fit_transform(X)
#       9 print(X)
#
# File c:\Users\91738\Desktop\dynamic-python-bankend\venv\Lib\site-packages\sklearn\utils\_set_output.py:316, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     314 @wraps(f)
#     315 def wrapped(self, X, *args, **kwargs):
# --> 316     data_to_wrap = f(self, X, *args, **kwargs)
#     317     if isinstance(data_to_wrap, tuple):
#     318         # only wrap the first output for cross decomposition
#     319         return_tuple = (
#     320             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     321             *data_to_wrap[1:],
#     322         )
#
# File c:\Users\91738\Desktop\dynamic-python-bankend\venv\Lib\site-packages\sklearn\base.py:1336, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1329     estimator._validate_params()
#    1331 with config_context(
#    1332     skip_parameter_validation=(
#    1333         prefer_skip_nested_validation or global_skip_validation
#    1334     )
#    1335 ):
# -> 1336     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\91738\Desktop\dynamic-python-bankend\venv\Lib\site-packages\sklearn\compose\_column_transformer.py:999, in ColumnTransformer.fit_transform(self, X, y, **params)
#     996 else:
#     997     routed_params = self._get_empty_routing()
# --> 999 result = self._call_func_on_transformers(
#    1000     X,
#    1001     y,
#    1002     _fit_transform_one,
#    1003     column_as_labels=False,
#    1004     routed_params=routed_params,
#    1005 )
#    1007 if not result:
#    1008     self._update_fitted_transformers([])
#
# File c:\Users\91738\Desktop\dynamic-python-bankend\venv\Lib\site-packages\sklearn\compose\_column_transformer.py:901, in ColumnTransformer._call_func_on_transformers(self, X, y, func, column_as_labels, routed_params)
#     889             extra_args = {}
#     890         jobs.append(
#     891             delayed(func)(
#     892                 transformer=clone(trans) if not fitted else trans,
#    (...)    898             )
#     899         )
# --> 901     return Parallel(n_jobs=self.n_jobs)(jobs)
#     903 except ValueError as e:
#     904     if "Expected 2D array, got 1D array instead" in str(e):
#
# File c:\Users\91738\Desktop\dynamic-python-bankend\venv\Lib\site-packages\sklearn\utils\parallel.py:91, in Parallel.__call__(self, iterable)
#      79 warning_filters = (
#      80     filters_func() if filters_func is not None else warnings.filters
#      81 )
#      83 iterable_with_config_and_warning_filters = (
#      84     (
#      85         _with_config_and_warning_filters(delayed_func, config, warning_filters),
#    (...)     89     for delayed_func, args, kwargs in iterable
#      90 )
# ---> 91 return super().__call__(iterable_with_config_and_warning_filters)
#
# File c:\Users\91738\Desktop\dynamic-python-bankend\venv\Lib\site-packages\joblib\parallel.py:1986, in Parallel.__call__(self, iterable)
#    1984     output = self._get_sequential_output(iterable)
#    1985     next(output)
# -> 1986     return output if self.return_generator else list(output)
#    1988 # Let's create an ID that uniquely identifies the current call. If the
#    1989 # call is interrupted early and that the same instance is immediately
#    1990 # reused, this id will be used to prevent workers that were
#    1991 # concurrently finalizing a task from the previous call to run the
#    1992 # callback.
#    1993 with self._lock:
#
# File c:\Users\91738\Desktop\dynamic-python-bankend\venv\Lib\site-packages\joblib\parallel.py:1914, in Parallel._get_sequential_output(self, iterable)
#    1912 self.n_dispatched_batches += 1
#    1913 self.n_dispatched_tasks += 1
# -> 1914 res = func(*args, **kwargs)
#    1915 self.n_completed_tasks += 1
#    1916 self.print_progress()
#
# File c:\Users\91738\Desktop\dynamic-python-bankend\venv\Lib\site-packages\sklearn\utils\parallel.py:184, in _FuncWrapper.__call__(self, *args, **kwargs)
#     180                 this_warning_filter_dict[special_key] = this_value.pattern
#     182         warnings.filterwarnings(**this_warning_filter_dict, append=True)
# --> 184 return self.function(*args, **kwargs)
#
# File c:\Users\91738\Desktop\dynamic-python-bankend\venv\Lib\site-packages\sklearn\pipeline.py:1484, in _fit_transform_one(transformer, X, y, weight, message_clsname, message, params)
#    1482 with _print_elapsed_time(message_clsname, message):
#    1483     if hasattr(transformer, "fit_transform"):
# -> 1484         res = transformer.fit_transform(X, y, **params.get("fit_transform", {}))
#    1485     else:
#    1486         res = transformer.fit(X, y, **params.get("fit", {})).transform(
#    1487             X, **params.get("transform", {})
#    1488         )
#
# File c:\Users\91738\Desktop\dynamic-python-bankend\venv\Lib\site-packages\sklearn\utils\_set_output.py:316, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     314 @wraps(f)
#     315 def wrapped(self, X, *args, **kwargs):
# --> 316     data_to_wrap = f(self, X, *args, **kwargs)
#     317     if isinstance(data_to_wrap, tuple):
#     318         # only wrap the first output for cross decomposition
#     319         return_tuple = (
#     320             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     321             *data_to_wrap[1:],
#     322         )
#
# File c:\Users\91738\Desktop\dynamic-python-bankend\venv\Lib\site-packages\sklearn\base.py:907, in TransformerMixin.fit_transform(self, X, y, **fit_params)
#     892         warnings.warn(
#     893             (
#     894                 f"This object ({self.__class__.__name__}) has a `transform`"
#    (...)    902             UserWarning,
#     903         )
#     905 if y is None:
#     906     # fit method of arity 1 (unsupervised transformation)
# --> 907     return self.fit(X, **fit_params).transform(X)
#     908 else:
#     909     # fit method of arity 2 (supervised transformation)
#     910     return self.fit(X, y, **fit_params).transform(X)
#
# File c:\Users\91738\Desktop\dynamic-python-bankend\venv\Lib\site-packages\sklearn\base.py:1336, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1329     estimator._validate_params()
#    1331 with config_context(
#    1332     skip_parameter_validation=(
#    1333         prefer_skip_nested_validation or global_skip_validation
#    1334     )
#    1335 ):
# -> 1336     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\91738\Desktop\dynamic-python-bankend\venv\Lib\site-packages\sklearn\preprocessing\_encoders.py:999, in OneHotEncoder.fit(self, X, y)
#     980 @_fit_context(prefer_skip_nested_validation=True)
#     981 def fit(self, X, y=None):
#     982     """
#     983     Fit OneHotEncoder to X.
#     984
#    (...)    997         Fitted encoder.
#     998     """
# --> 999     self._fit(
#    1000         X,
#    1001         handle_unknown=self.handle_unknown,
#    1002         ensure_all_finite="allow-nan",
#    1003     )
#    1004     self._set_drop_idx()
#    1005     self._n_features_outs = self._compute_n_features_outs()
#
# File c:\Users\91738\Desktop\dynamic-python-bankend\venv\Lib\site-packages\sklearn\preprocessing\_encoders.py:86, in _BaseEncoder._fit(self, X, handle_unknown, ensure_all_finite, return_counts, return_and_ignore_missing_for_infrequent)
#      84 self._check_infrequent_enabled()
#      85 validate_data(self, X=X, reset=True, skip_check_array=True)
# ---> 86 X_list, n_samples, n_features = self._check_X(
#      87     X, ensure_all_finite=ensure_all_finite
#      88 )
#      89 self.n_features_in_ = n_features
#      91 if self.categories != "auto":
#
# File c:\Users\91738\Desktop\dynamic-python-bankend\venv\Lib\site-packages\sklearn\preprocessing\_encoders.py:53, in _BaseEncoder._check_X(self, X, ensure_all_finite)
#      40 """
#      41 Perform custom check_array:
#      42 - convert list of strings to object dtype
#    (...)     49
#      50 """
#      51 if not (hasattr(X, "iloc") and getattr(X, "ndim", 0) == 2):
#      52     # if not a dataframe, do normal check_array validation
# ---> 53     X_temp = check_array(X, dtype=None, ensure_all_finite=ensure_all_finite)
#      54     if not hasattr(X, "dtype") and np.issubdtype(X_temp.dtype, np.str_):
#      55         X = check_array(X, dtype=object, ensure_all_finite=ensure_all_finite)
#
# File c:\Users\91738\Desktop\dynamic-python-bankend\venv\Lib\site-packages\sklearn\utils\validation.py:981, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, ensure_all_finite, ensure_non_negative, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     979 if sp.issparse(array):
#     980     _ensure_no_complex_data(array)
# --> 981     array = _ensure_sparse_format(
#     982         array,
#     983         accept_sparse=accept_sparse,
#     984         dtype=dtype,
#     985         copy=copy,
#     986         ensure_all_finite=ensure_all_finite,
#     987         accept_large_sparse=accept_large_sparse,
#     988         estimator_name=estimator_name,
#     989         input_name=input_name,
#     990     )
#     991     if ensure_2d and array.ndim < 2:
#     992         raise ValueError(
#     993             f"Expected 2D input, got input with shape {array.shape}.\n"
#     994             "Reshape your data either using array.reshape(-1, 1) if "
#     995             "your data has a single feature or array.reshape(1, -1) "
#     996             "if it contains a single sample."
#     997         )
#
# File c:\Users\91738\Desktop\dynamic-python-bankend\venv\Lib\site-packages\sklearn\utils\validation.py:602, in _ensure_sparse_format(sparse_container, accept_sparse, dtype, copy, ensure_all_finite, accept_large_sparse, estimator_name, input_name)
#     600 if accept_sparse is False:
#     601     padded_input = " for " + input_name if input_name else ""
# --> 602     raise TypeError(
#     603         f"Sparse data was passed{padded_input}, but dense data is required. "
#     604         "Use '.toarray()' to convert to a dense numpy array."
#     605     )
#     606 elif isinstance(accept_sparse, (list, tuple)):
#     607     if len(accept_sparse) == 0:
#
# TypeError: Sparse data was passed, but dense data is required. Use '.toarray()' to convert to a dense numpy array.

# %% [markdown]
# Encoding the Dependent Variable

# %%
from sklearn.preprocessing import  LabelEncoder

le = LabelEncoder()
Z = le.fit_transform(Z)
print(Z)
# Out:
# [1 1 0 1 0 0 1 1 2 1 1 0 1 0 1]
