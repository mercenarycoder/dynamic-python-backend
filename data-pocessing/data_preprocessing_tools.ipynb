# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# Importing the dataset

# %%
dataset = pd.read_csv("./retail_sales.csv")
X = dataset.iloc[:, :-3].values 
Y = dataset.iloc[:, -4:]
print(Y)
# Out:
#     Quantity    Price   Sales eligible for AI
# 0          2  55000.0  110000             yes
# 1          3  30000.0   90000             yes
# 2          5      NaN   10000              no
# 3          2  15000.0   30000             yes
# 4         10   1500.0   15000              no
# 5          8    700.0    5600              no
# 6          4  25000.0  100000             yes
# 7          1  60000.0     NaN             yes
# 8          2      NaN     yes             NaN
# 9          3  12000.0   36000             yes
# 10         2  45000.0   90000             yes
# 11         6   3500.0   21000              no
# 12         5  32000.0  160000             yes
# 13         7   8000.0   56000              no
# 14         2  58000.0  116000             yes

# %% [markdown]
# Fill the missing data so that it can be consistent

# %%
from sklearn.impute import SimpleImputer

data = np.array(Y)
imputer = SimpleImputer(missing_values=np.nan, strategy='mean')
result = imputer.fit_transform(data)
np.set_printoptions(suppress=True)
print(result)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 5
#       1 from sklearn.impute import SimpleImputer
#       2
#       3 data = np.array(Y)
#       4 imputer = SimpleImputer(missing_values=np.nan, strategy='mean')
# ----> 5 result = imputer.fit_transform(data)
#       6 np.set_printoptions(suppress=True)
#       7 print(result)
#
# File c:\Users\91738\Desktop\dynamic-python-bankend\venv\Lib\site-packages\sklearn\utils\_set_output.py:316, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     314 @wraps(f)
#     315 def wrapped(self, X, *args, **kwargs):
# --> 316     data_to_wrap = f(self, X, *args, **kwargs)
#     317     if isinstance(data_to_wrap, tuple):
#     318         # only wrap the first output for cross decomposition
#     319         return_tuple = (
#     320             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     321             *data_to_wrap[1:],
#     322         )
#
# File c:\Users\91738\Desktop\dynamic-python-bankend\venv\Lib\site-packages\sklearn\base.py:907, in TransformerMixin.fit_transform(self, X, y, **fit_params)
#     892         warnings.warn(
#     893             (
#     894                 f"This object ({self.__class__.__name__}) has a `transform`"
#    (...)    902             UserWarning,
#     903         )
#     905 if y is None:
#     906     # fit method of arity 1 (unsupervised transformation)
# --> 907     return self.fit(X, **fit_params).transform(X)
#     908 else:
#     909     # fit method of arity 2 (supervised transformation)
#     910     return self.fit(X, y, **fit_params).transform(X)
#
# File c:\Users\91738\Desktop\dynamic-python-bankend\venv\Lib\site-packages\sklearn\base.py:1336, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1329     estimator._validate_params()
#    1331 with config_context(
#    1332     skip_parameter_validation=(
#    1333         prefer_skip_nested_validation or global_skip_validation
#    1334     )
#    1335 ):
# -> 1336     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\91738\Desktop\dynamic-python-bankend\venv\Lib\site-packages\sklearn\impute\_base.py:447, in SimpleImputer.fit(self, X, y)
#     429 @_fit_context(prefer_skip_nested_validation=True)
#     430 def fit(self, X, y=None):
#     431     """Fit the imputer on `X`.
#     432
#     433     Parameters
#    (...)    445         Fitted estimator.
#     446     """
# --> 447     X = self._validate_input(X, in_fit=True)
#     449     # default fill_value is 0 for numerical input and "missing_value"
#     450     # otherwise
#     451     if self.fill_value is None:
#
# File c:\Users\91738\Desktop\dynamic-python-bankend\venv\Lib\site-packages\sklearn\impute\_base.py:372, in SimpleImputer._validate_input(self, X, in_fit)
#     366 if "could not convert" in str(ve):
#     367     new_ve = ValueError(
#     368         "Cannot use {} strategy with non-numeric data:\n{}".format(
#     369             self.strategy, ve
#     370         )
#     371     )
# --> 372     raise new_ve from None
#     373 else:
#     374     raise ve
#
# ValueError: Cannot use mean strategy with non-numeric data:
# could not convert string to float: 'yes'

# %% [markdown]
# Encoding the Independent Variable

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
 
ct = ColumnTransformer(transformers=[('encoder', OneHotEncoder(), [1])], remainder='passthrough')
X = np.array(ct.fit_transform(X))
print(X)

# %% [markdown]
# Encoding the Dependent Variable

# %%
from sklearn.preprocessing import  LabelEncoder

le = LabelEncoder()
Y = le.fit_transform(Y)
print(Y)
