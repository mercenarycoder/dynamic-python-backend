# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# Importing the dataset

# %%
dataset = pd.read_csv("./retail_sales.csv")
print(dataset.head)
# Out:
# <bound method NDFrame.head of     OrderID          State       City      Product     Category  Quantity  \
# 0      1001      Karnataka  Bangalore       Laptop  Electronics         2
# 1      1002    Maharashtra     Mumbai        Phone  Electronics         3
# 2      1003      Telangana  Hyderabad   Headphones  Accessories         5
# 3      1004     Tamil Nadu    Chennai      Monitor  Electronics         2
# 4      1005          Delhi  New Delhi     Keyboard  Accessories        10
# 5      1006      Karnataka     Mysore        Mouse  Accessories         8
# 6      1007    West Bengal    Kolkata       Tablet  Electronics         4
# 7      1008    Maharashtra       Pune       Laptop  Electronics         1
# 8      1009        Gujarat  Ahmedabad        Phone  Electronics         2
# 9      1010      Rajasthan     Jaipur      Printer  Electronics         3
# 10     1011  Uttar Pradesh    Lucknow       Camera  Electronics         2
# ...
